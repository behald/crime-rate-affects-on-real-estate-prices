# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2  = pd.read_csv("C:\\Users\\divay\\Downloads\\archive (5)\merged_dataset.csv")
df2
# Out:
#         Year   index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0   41.080000     Atlanta, GA    490584.0          8033.0
# 1     1975.0   30.750000     Chicago, IL   3150000.0         37160.0
# 2     1975.0   36.350000   Cleveland, OH    659931.0         10403.0
# 3     1975.0   20.910000     Oakland, CA    337748.0          5900.0
# 4     1975.0   20.385000     Seattle, WA    503500.0          3971.0
# ...      ...         ...             ...         ...             ...
# 3472  2015.0  194.641250       Tulsa, OK    401520.0          3628.0
# 3473     NaN         NaN             NaN         NaN             NaN
# 3474  2015.0  248.035833  Washington, DC    672228.0          8084.0
# 3475     NaN         NaN             NaN         NaN             NaN
# 3476  2015.0  176.280000     Wichita, KS    389824.0          3839.0
#
#       Homicides   Rapes  Assaults  Robberies
# 0         185.0   443.0    3518.0     3887.0
# 1         818.0  1657.0   12514.0    22171.0
# ...

# %%
df2['index_nsa'] = round(df2['index_nsa'])

# %%
df2
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 1     1975.0       31.0     Chicago, IL   3150000.0         37160.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# ...      ...        ...             ...         ...             ...
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3473     NaN        NaN             NaN         NaN             NaN
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3475     NaN        NaN             NaN         NaN             NaN
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides   Rapes  Assaults  Robberies
# 0         185.0   443.0    3518.0     3887.0
# 1         818.0  1657.0   12514.0    22171.0
# ...

# %%
df2.isna().sum()
# Out:
# Year              1736
# index_nsa         1736
# City, State       1736
# Population        1763
# Violent Crimes    1769
# Homicides         1768
# Rapes             1768
# Assaults          1769
# Robberies         1768
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = df2

df = pd.DataFrame(df2)

# Boxplot to visualize outliers
plt.figure(figsize=(10, 10))
sns.boxplot(data=df)
plt.title('Boxplot for Outlier Detection')
plt.xlabel('Values')
plt.show()

# %%
df2['Year'].max()
# Out:
# 2015.0

# %%
df2
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 1     1975.0       31.0     Chicago, IL   3150000.0         37160.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# ...      ...        ...             ...         ...             ...
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3473     NaN        NaN             NaN         NaN             NaN
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3475     NaN        NaN             NaN         NaN             NaN
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides   Rapes  Assaults  Robberies
# 0         185.0   443.0    3518.0     3887.0
# 1         818.0  1657.0   12514.0    22171.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477 entries, 0 to 3476
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            1741 non-null   float64
#  1   index_nsa       1741 non-null   float64
#  2   City, State     1741 non-null   object
#  3   Population      1714 non-null   float64
#  4   Violent Crimes  1708 non-null   float64
#  5   Homicides       1709 non-null   float64
#  6   Rapes           1709 non-null   float64
#  7   Assaults        1708 non-null   float64
#  8   Robberies       1709 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 244.6+ KB

# %%
df2.duplicated().sum()
# Out:
# 1735

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2 = df2.drop_duplicates()

# %%
df2
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 1     1975.0       31.0     Chicago, IL   3150000.0         37160.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0      227.0       Tampa, FL    364383.0          2298.0
# 3470  2015.0      198.0      Tucson, AZ    529675.0          3472.0
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides   Rapes  Assaults  Robberies
# 0         185.0   443.0    3518.0     3887.0
# 1         818.0  1657.0   12514.0    22171.0
# ...

# %%
df2.isna().sum()
# Out:
# Year               1
# index_nsa          1
# City, State        1
# Population        28
# Violent Crimes    34
# Homicides         33
# Rapes             33
# Assaults          34
# Robberies         33
# dtype: int64

# %%
sns.distplot(df2['Population'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Population', ylabel='Density'>

# %%
df2['Population'].skew()
# Out:
# 2.839145641907022

# %%
sns.distplot(df2['Violent Crimes'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Violent Crimes', ylabel='Density'>

# %%
sns.distplot(df2['Assaults'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Assaults', ylabel='Density'>

# %%
sns.distplot(df2['Robberies'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Robberies', ylabel='Density'>

# %%
sns.distplot(df2['Homicides'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Homicides', ylabel='Density'>

# %%
sns.distplot(df2['Rapes'])
# Out:
# C:\Users\divay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rapes', ylabel='Density'>

# %%
df2 = df2.fillna(df.median())
# Out:
# C:\Users\divay\AppData\Local\Temp\ipykernel_7900\2170583410.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2 = df2.fillna(df.median())

# %%
df2.isna().sum()
# Out:
# Year              0
# index_nsa         0
# City, State       1
# Population        0
# Violent Crimes    0
# Homicides         0
# Rapes             0
# Assaults          0
# Robberies         0
# dtype: int64

# %%
df2
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 1     1975.0       31.0     Chicago, IL   3150000.0         37160.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0      227.0       Tampa, FL    364383.0          2298.0
# 3470  2015.0      198.0      Tucson, AZ    529675.0          3472.0
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides   Rapes  Assaults  Robberies
# 0         185.0   443.0    3518.0     3887.0
# 1         818.0  1657.0   12514.0    22171.0
# ...

# %%
Q1 = df2['Population'].quantile(0.25)
Q3 = df2['Population'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers using the bounds
outliers = pd.DataFrame(df2[(df2['Population'] >= lower_bound) & (df2['Population'] <= upper_bound)])


# Remove outliers from the DataFrame
cleaned_df = outliers

# %%
cleaned_df
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# 5     1996.0      110.0             NaN    470970.0          5119.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0      227.0       Tampa, FL    364383.0          2298.0
# 3470  2015.0      198.0      Tucson, AZ    529675.0          3472.0
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides  Rapes  Assaults  Robberies
# 0         185.0  443.0    3518.0     3887.0
# 2         288.0  491.0    2524.0     7100.0
# ...

# %%
# Boxplot to visualize outliers
plt.figure(figsize=(10, 10))
sns.boxplot(data = cleaned_df)
plt.title('Boxplot for Outlier Detection')
plt.xlabel('Values')
plt.show()

# %%
cleaned_df.isna().sum()
# Out:
# Year              0
# index_nsa         0
# City, State       1
# Population        0
# Violent Crimes    0
# Homicides         0
# Rapes             0
# Assaults          0
# Robberies         0
# dtype: int64

# %%
cleaned_df
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0       41.0     Atlanta, GA    490584.0          8033.0
# 2     1975.0       36.0   Cleveland, OH    659931.0         10403.0
# 3     1975.0       21.0     Oakland, CA    337748.0          5900.0
# 4     1975.0       20.0     Seattle, WA    503500.0          3971.0
# 5     1996.0      110.0             NaN    470970.0          5119.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0      227.0       Tampa, FL    364383.0          2298.0
# 3470  2015.0      198.0      Tucson, AZ    529675.0          3472.0
# 3472  2015.0      195.0       Tulsa, OK    401520.0          3628.0
# 3474  2015.0      248.0  Washington, DC    672228.0          8084.0
# 3476  2015.0      176.0     Wichita, KS    389824.0          3839.0
#
#       Homicides  Rapes  Assaults  Robberies
# 0         185.0  443.0    3518.0     3887.0
# 2         288.0  491.0    2524.0     7100.0
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 3476
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            1575 non-null   float64
#  1   index_nsa       1575 non-null   float64
#  2   City, State     1574 non-null   object
#  3   Population      1575 non-null   float64
#  4   Violent Crimes  1575 non-null   float64
#  5   Homicides       1575 non-null   float64
#  6   Rapes           1575 non-null   float64
#  7   Assaults        1575 non-null   float64
#  8   Robberies       1575 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 123.0+ KB

# %%
cleaned_df['index_nsa']
# Out:
# 0        41.0
# 2        36.0
# 3        21.0
# 4        20.0
# 5       110.0
#         ...
# 3468    227.0
# 3470    198.0
# 3472    195.0
# 3474    248.0
# 3476    176.0
# Name: index_nsa, Length: 1575, dtype: float64

# %%
cleaned_df['index_nsa'] = cleaned_df['index_nsa'].astype('int')

# %%
cleaned_df['index_nsa'] = cleaned_df['index_nsa'].astype('int')

# %%
cleaned_df['index_nsa'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1575 entries, 0 to 3476
# Series name: index_nsa
# Non-Null Count  Dtype
# --------------  -----
# 1575 non-null   int32
# dtypes: int32(1)
# memory usage: 18.5 KB

# %%
cleaned_df.describe()
# Out:
#               Year    index_nsa    Population  Violent Crimes    Homicides  \
# count  1575.000000  1575.000000  1.575000e+03     1575.000000  1575.000000
# mean   1995.586667   125.025397  4.833271e+05     5920.663492    82.733333
# std      11.376594    62.552804  1.958850e+05     4267.245772    86.657925
# min    1975.000000    20.000000  1.129940e+05      385.000000     1.000000
# 25%    1986.000000    75.000000  3.483645e+05     3098.000000    33.000000
# 50%    1995.000000   109.000000  4.394070e+05     4707.000000    56.000000
# 75%    2005.000000   167.000000  6.021560e+05     7497.500000    95.000000
# max    2015.000000   386.000000  1.091523e+06    28358.000000   686.000000
#
#              Rapes      Assaults     Robberies
# count  1575.000000   1575.000000   1575.000000
# mean    326.213968   3039.226032   2472.733333
# std     209.125642   2217.007258   2097.585401
# min      34.000000    264.000000     83.000000
# 25%     187.500000   1550.500000   1052.500000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns



plt.figure(figsize=(50, 50))
sns.barplot(x= cleaned_df['City, State'], y=cleaned_df['index_nsa'], label='Uber', color='yellow')
plt.xlabel('CITY AND STATE')
plt.ylabel('index_nsa')
plt.title('% CHANGE IN HOUSING PRICES OF THE DIFFERENT CITY AND STATES')
plt.legend()
plt.show()

# %%
# Correlation matrix
print("\nCorrelation Matrix:")
correlation_matrix = df2.corr()
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                     Year  index_nsa  Population  Violent Crimes  Homicides  \
# Year            1.000000   0.876076    0.074983       -0.037448  -0.103364
# index_nsa       0.876076   1.000000    0.061850       -0.063788  -0.107133
# Population      0.074983   0.061850    1.000000        0.808962   0.811110
# Violent Crimes -0.037448  -0.063788    0.808962        1.000000   0.887609
# Homicides      -0.103364  -0.107133    0.811110        0.887609   1.000000
# Rapes          -0.122355  -0.133347    0.806393        0.911565   0.834049
# Assaults        0.046257   0.009538    0.752392        0.969533   0.799300
# Robberies      -0.110884  -0.126811    0.809572        0.971992   0.916674
#
#                    Rapes  Assaults  Robberies
# Year           -0.122355  0.046257  -0.110884
# index_nsa      -0.133347  0.009538  -0.126811
# Population      0.806393  0.752392   0.809572
# Violent Crimes  0.911565  0.969533   0.971992
# ...

# %%
# Visualize correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = df2['Year']
y_values1 = df2['index_nsa']
y_values2 = df2['Violent Crimes']

# Plotting the line graph for two sets of values
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.plot(x_values, y_values1, marker='o', linestyle='-', color='blue', label='Dataset 1')
plt.plot(x_values, y_values2, marker='s', linestyle='--', color='red', label='Dataset 2')

# Adding title and labels
plt.title('Line Graph with Two Datasets')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
cleaned_df
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0         41     Atlanta, GA    490584.0          8033.0
# 2     1975.0         36   Cleveland, OH    659931.0         10403.0
# 3     1975.0         21     Oakland, CA    337748.0          5900.0
# 4     1975.0         20     Seattle, WA    503500.0          3971.0
# 5     1996.0        110             NaN    470970.0          5119.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0        227       Tampa, FL    364383.0          2298.0
# 3470  2015.0        198      Tucson, AZ    529675.0          3472.0
# 3472  2015.0        195       Tulsa, OK    401520.0          3628.0
# 3474  2015.0        248  Washington, DC    672228.0          8084.0
# 3476  2015.0        176     Wichita, KS    389824.0          3839.0
#
#       Homicides  Rapes  Assaults  Robberies
# 0         185.0  443.0    3518.0     3887.0
# 2         288.0  491.0    2524.0     7100.0
# ...

# %%
price_year_variation = pd.DataFrame(cleaned_df.groupby('index_nsa')['Year'])
price_year_variation
# Out:
#        0                                                  1
# 0     20             4    1975.0
# Name: Year, dtype: float64
# 1     21             3    1975.0
# Name: Year, dtype: float64
# 2     22            90    1977.0
# Name: Year, dtype: float64
# 3     23            48    1976.0
# Name: Year, dtype: float64
# 4     24            38    1976.0
# Name: Year, dtype: float64
# ..   ...                                                ...
# 261  323  2662    2006.0
# 3460    2015.0
# Name: Year, dtyp...
# 262  326          3394    2015.0
# Name: Year, dtype: float64
# 263  333  3414    2015.0
# 3416    2015.0
# Name: Year, dtyp...
# 264  374          2644    2006.0
# Name: Year, dtype: float64
# 265  386          2732    2007.0
# Name: Year, dtype: float64
#
# [266 rows x 2 columns]

# %%
top_violent_crimes = list(cleaned_df.groupby('City, State')['Violent Crimes'].agg('sum').sort_values(ascending=False).head(10).index); 
top_violent_crimes
# Out:
# ['Detroit, MI',
#  'Baltimore, MD',
#  'Washington, DC',
#  'Atlanta, GA',
#  'Memphis, TN',
#  'Dallas, TX',
#  'Miami, FL',
#  'Boston, MA',
#  'Cleveland, OH',
#  'Jacksonville, FL']

# %%
sns.catplot(data=cleaned_df[cleaned_df['City, State'].isin(top_violent_crimes)], x="Violent Crimes", y="City, State", kind="bar")

# %%
import matplotlib.pyplot as plt
import seaborn as sns



plt.figure(figsize=(50, 50))
sns.barplot(x= cleaned_df['City, State'], y=cleaned_df['Violent Crimes'], label='violent_crimes', color='yellow')
plt.xlabel('CITY AND STATE')
plt.ylabel('index_nsa')
plt.title('% CHANGE IN HOUSING PRICES OF THE DIFFERENT CITY AND STATES')
plt.legend()
plt.show()

# %%
cleaned_df

# %%
import matplotlib.pyplot as plt

# Sample data
categories = price_year_variation.index
values = price_year_variation

# Plotting the bar graph
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.bar(categories, values, color='skyblue')

# Adding title and labels
plt.title('Bar Graph Example')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = cleaned_df['City, State']
values1 = cleaned_df['Homicides']
values2 = cleaned_df['Rapes']
values3 = cleaned_df['Assaults']
values4 = cleaned_df['Robberies']


# Creating positions for bars
bar_positions = np.arange(len(categories))
bar_width = 0.2  # Width of each bar

# Plotting the bars for each dataset
plt.figure(figsize=(10, 6))  # Optional: Adjusting figure size

plt.bar(bar_positions - 1.5 * bar_width, values1, bar_width, label='Value 1')
plt.bar(bar_positions - 0.5 * bar_width, values2, bar_width, label='Value 2')
plt.bar(bar_positions + 0.5 * bar_width, values3, bar_width, label='Value 3')
plt.bar(bar_positions + 1.5 * bar_width, values4, bar_width, label='Value 4')


# Adding x-axis labels
plt.xticks(bar_positions, categories)

# Adding title and labels
plt.title('Bar Graph with Four Columns')
plt.xlabel('Categories')
plt.ylabel('Values')

# Adding legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = cleaned_df['City, State']
values1 = cleaned_df['Homicides']
values2 = cleaned_df['Rapes']
values3 = cleaned_df['Assaults']
values4 = cleaned_df['Robberies']
values5 = cleaned_df['Violent Crimes']


# Creating positions for bars
bar_positions = np.arange(len(categories))

# Plotting the stacked bar chart
plt.figure(figsize=(15, 50))  # Optional: Adjusting figure size
plt.bar(bar_positions, values1, color='skyblue', label='Value 1')
plt.bar(bar_positions, values2, bottom=values1, color='orange', label='Value 2')
plt.bar(bar_positions, values3, bottom=np.array(values1) + np.array(values2), color='green', label='Value 3')
plt.bar(bar_positions, values4, bottom=np.array(values1) + np.array(values2) + np.array(values3), color='red', label='Value 4')
plt.bar(bar_positions, values5, bottom=np.array(values1) + np.array(values2) + np.array(values3) + np.array(values4), color='purple', label='Value 5')

# Adding x-axis labels
plt.xticks(bar_positions, categories)

# Adding title and labels
plt.title('Stacked Bar Chart with 5 Columns')
plt.xlabel('Categories')
plt.ylabel('Values')

# Adding legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# #### REALTION BETWEEN INDEX PRICES AND HOMICIDES

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = cleaned_df['Homicides']
y_values = cleaned_df['index_nsa']

# Plotting the scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.scatter(x_values, y_values, color='blue', marker='o', label='Scatter Plot')

# Adding title and labels
plt.title('Simple Scatter Plot')
plt.xlabel('Homicides')
plt.ylabel('index_nsa')

# Adding gridlines (optional)
plt.grid(True)

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = cleaned_df['Rapes']
y_values = cleaned_df['index_nsa']

# Plotting the scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.scatter(x_values, y_values, color='blue', marker='o', label='Scatter Plot')

# Adding title and labels
plt.title('Simple Scatter Plot')
plt.xlabel('Rapes')
plt.ylabel('index_nsa')

# Adding gridlines (optional)
plt.grid(True)

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = cleaned_df['Assaults']
y_values = cleaned_df['index_nsa']

# Plotting the scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.scatter(x_values, y_values, color='blue', marker='o', label='Scatter Plot')

# Adding title and labels
plt.title('Simple Scatter Plot')
plt.xlabel('Assaults')
plt.ylabel('index_nsa')

# Adding gridlines (optional)
plt.grid(True)

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = cleaned_df['Robberies']
y_values = cleaned_df['index_nsa']

# Plotting the scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjusting figure size
plt.scatter(x_values, y_values, color='blue', marker='o', label='Scatter Plot')

# Adding title and labels
plt.title('Simple Scatter Plot')
plt.xlabel('Robberies')
plt.ylabel('index_nsa')

# Adding gridlines (optional)
plt.grid(True)

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
cleaned_df
# Out:
#         Year  index_nsa     City, State  Population  Violent Crimes  \
# 0     1975.0         41     Atlanta, GA    490584.0          8033.0
# 2     1975.0         36   Cleveland, OH    659931.0         10403.0
# 3     1975.0         21     Oakland, CA    337748.0          5900.0
# 4     1975.0         20     Seattle, WA    503500.0          3971.0
# 5     1996.0        110             NaN    470970.0          5119.0
# ...      ...        ...             ...         ...             ...
# 3468  2015.0        227       Tampa, FL    364383.0          2298.0
# 3470  2015.0        198      Tucson, AZ    529675.0          3472.0
# 3472  2015.0        195       Tulsa, OK    401520.0          3628.0
# 3474  2015.0        248  Washington, DC    672228.0          8084.0
# 3476  2015.0        176     Wichita, KS    389824.0          3839.0
#
#       Homicides  Rapes  Assaults  Robberies
# 0         185.0  443.0    3518.0     3887.0
# 2         288.0  491.0    2524.0     7100.0
# ...

# %%
df3 = pd.read_csv("C:\\Users\\divay\\Downloads\\archive (5)\\report.csv")
df3
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0            1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1            1975     TX22001       Arlington, TX    112478.0           278.0
# 2            1975     GAAPD00         Atlanta, GA    490584.0          8033.0
# 3            1975     CO00101          Aurora, CO    116656.0           611.0
# 4            1975     TX22701          Austin, TX    300400.0          1215.0
# ...           ...         ...                 ...         ...             ...
# 2824         2015     OK07205           Tulsa, OK    401520.0          3628.0
# 2825         2015     VA12800  Virginia Beach, VA    452797.0           626.0
# 2826         2015     DCMPD00      Washington, DC    672228.0          8084.0
# 2827         2015     KS08703         Wichita, KS    389824.0          3839.0
# 2828         2015         NaN       United States         NaN       1197704.0
#
# ...

# %%
df3.isna().sum()
# Out:
# report_year              0
# agency_code             41
# agency_jurisdiction      0
# population              69
# violent_crimes          35
# homicides               34
# rapes                   75
# assaults                76
# robberies               75
# months_reported        137
# crimes_percapita        35
# homicides_percapita     34
# rapes_percapita         75
# assaults_percapita      76
# robberies_percapita     75
# dtype: int64

# %%
df3 = df3.dropna()

# %%
top_crime_areas = list(df3.groupby('agency_jurisdiction')['robberies'].agg('sum').sort_values(ascending=False).head(10).index); 
top_crime_areas
# Out:
# ['New York City, NY',
#  'Chicago, IL',
#  'Los Angeles, CA',
#  'Detroit, MI',
#  'Philadelphia, PA',
#  'Houston, TX',
#  'Baltimore, MD',
#  'Dallas, TX',
#  'Washington, DC',
#  'San Francisco, CA']

# %%
sns.catplot(data=df3[df3['agency_jurisdiction'].isin(top_crime_areas)], x="robberies", y="agency_jurisdiction", kind="bar")
